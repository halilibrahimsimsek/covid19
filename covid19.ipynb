# %%
import pandas as pd
import numpy as np
import statsmodels.api as sm
from sklearn.metrics import r2_score

# %%
data = pd.read_csv("covid19_italy.csv")

# %%
print(data.head())
# Out:
#    SNo                 Date Country  RegionCode RegionName  ProvinceCode  \
# 0    0  2020-02-24 18:00:00     ITA          13    Abruzzo            69
# 1    1  2020-02-24 18:00:00     ITA          13    Abruzzo            66
# 2    2  2020-02-24 18:00:00     ITA          13    Abruzzo            68
# 3    3  2020-02-24 18:00:00     ITA          13    Abruzzo            67
# 4    4  2020-02-24 18:00:00     ITA          13    Abruzzo           979
#
#                            ProvinceName ProvinceAbbreviation   Latitude  \
# 0                                Chieti                   CH  42.351032
# 1                              L'Aquila                   AQ  42.351222
# 2                               Pescara                   PE  42.464584
# 3                                Teramo                   TE  42.658918
# 4  In fase di definizione/aggiornamento                  NaN   0.000000
#
#    Longitude  TotalPositiveCases
# 0  14.167546                   0
# 1  13.398438                   0
# 2  14.213648                   0
# 3  13.704400                   0
# 4   0.000000                   0

# %%
data['Date'].str.replace("-","")
# Out:
# 0       20200224 18:00:00
# 1       20200224 18:00:00
# 2       20200224 18:00:00
# 3       20200224 18:00:00
# 4       20200224 18:00:00
# 5       20200224 18:00:00
# 6       20200224 18:00:00
# 7       20200224 18:00:00
# 8       20200224 18:00:00
# 9       20200224 18:00:00
# 10      20200224 18:00:00
# 11      20200224 18:00:00
# 12      20200224 18:00:00
# 13      20200224 18:00:00
# 14      20200224 18:00:00
# 15      20200224 18:00:00
# 16      20200224 18:00:00
# 17      20200224 18:00:00
# 18      20200224 18:00:00
# 19      20200224 18:00:00
# 20      20200224 18:00:00
# 21      20200224 18:00:00
# 22      20200224 18:00:00
# 23      20200224 18:00:00
# 24      20200224 18:00:00
# 25      20200224 18:00:00
# 26      20200224 18:00:00
# 27      20200224 18:00:00
# 28      20200224 18:00:00
# 29      20200224 18:00:00
#               ...
# 3042    20200318 17:00:00
# 3043    20200318 17:00:00
# 3044    20200318 17:00:00
# 3045    20200318 17:00:00
# 3046    20200318 17:00:00
# 3047    20200318 17:00:00
# 3048    20200318 17:00:00
# 3049    20200318 17:00:00
# 3050    20200318 17:00:00
# 3051    20200318 17:00:00
# 3052    20200318 17:00:00
# 3053    20200318 17:00:00
# 3054    20200318 17:00:00
# 3055    20200318 17:00:00
# 3056    20200318 17:00:00
# 3057    20200318 17:00:00
# 3058    20200318 17:00:00
# 3059    20200318 17:00:00
# 3060    20200318 17:00:00
# 3061    20200318 17:00:00
# 3062    20200318 17:00:00
# 3063    20200318 17:00:00
# 3064    20200318 17:00:00
# 3065    20200318 17:00:00
# 3066    20200318 17:00:00
# 3067    20200318 17:00:00
# 3068    20200318 17:00:00
# 3069    20200318 17:00:00
# 3070    20200318 17:00:00
# 3071    20200318 17:00:00
# Name: Date, Length: 3072, dtype: object

# %%
data['Date'] = data['Date'].astype('datetime64[ns]')

# %%
date = data['Date'].dt.strftime("%Y%m%d").astype(int)

# %%
date = pd.DataFrame(date.values,columns = ["date"])

# %%
print(date.head())
# Out:
#        date
# 0  20200224
# 1  20200224
# 2  20200224
# 3  20200224
# 4  20200224

# %%
region = pd.DataFrame(data['RegionCode'].values,columns = ["RegionCode"])

# %%
print(region.head())
# Out:
#    RegionCode
# 0          13
# 1          13
# 2          13
# 3          13
# 4          13

# %%
province= data['ProvinceCode']

# %%
print(province.head())
# Out:
# 0     69
# 1     66
# 2     68
# 3     67
# 4    979
# Name: ProvinceCode, dtype: int64

# %%
positive_cases = data['TotalPositiveCases']

# %%
print(positive_cases.head())
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: TotalPositiveCases, dtype: int64

# %%
result = pd.concat([date,province,region],axis=1)

# %%
print(result)
# Out:
#           date  ProvinceCode  RegionCode
# 0     20200224            69          13
# 1     20200224            66          13
# 2     20200224            68          13
# 3     20200224            67          13
# 4     20200224           979          13
# 5     20200224            77          17
# 6     20200224            76          17
# 7     20200224           980          17
# 8     20200224            21           4
# 9     20200224           981           4
# 10    20200224            79          18
# 11    20200224            78          18
# 12    20200224           101          18
# 13    20200224            80          18
# 14    20200224           102          18
# 15    20200224           982          18
# 16    20200224            64          15
# 17    20200224            62          15
# 18    20200224            61          15
# 19    20200224            63          15
# 20    20200224            65          15
# 21    20200224           983          15
# 22    20200224            37           8
# 23    20200224            38           8
# 24    20200224            40           8
# 25    20200224            36           8
# 26    20200224            34           8
# 27    20200224            33           8
# 28    20200224            39           8
# 29    20200224            35           8
# ...        ...           ...         ...
# 3042  20200318            88          19
# 3043  20200318            89          19
# 3044  20200318            81          19
# 3045  20200318           994          19
# 3046  20200318            51           9
# 3047  20200318            48           9
# 3048  20200318            53           9
# 3049  20200318            49           9
# 3050  20200318            46           9
# 3051  20200318            45           9
# 3052  20200318            50           9
# 3053  20200318            47           9
# 3054  20200318           100           9
# 3055  20200318            52           9
# 3056  20200318           995           9
# 3057  20200318            22           4
# 3058  20200318           996           4
# 3059  20200318            54          10
# 3060  20200318            55          10
# 3061  20200318           997          10
# 3062  20200318             7           2
# 3063  20200318           998           2
# 3064  20200318            25           5
# 3065  20200318            28           5
# 3066  20200318            29           5
# 3067  20200318            26           5
# 3068  20200318            27           5
# 3069  20200318            23           5
# 3070  20200318            24           5
# 3071  20200318           999           5
#
# [3072 rows x 3 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test,y_train,y_test = train_test_split(result,positive_cases,test_size=0.33, random_state=0)

# %%
from sklearn.linear_model import LinearRegression

# %%
l_reg = LinearRegression()

# %%
l_reg.fit(x_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
l_pre = l_reg.predict(x_test)

# %%
print(r2_score(y_test,l_pre))
# Out:
# 0.0636491244506261

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
r_reg = RandomForestRegressor(10,random_state=10)

# %%
r_reg.fit(x_train,y_train)
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#                       max_features='auto', max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, n_estimators=10,
#                       n_jobs=None, oob_score=False, random_state=10, verbose=0,
#                       warm_start=False)

# %%
p_pred = r_reg.predict(x_test)

# %%
print(r2_score(y_test,p_pred))
# Out:
# 0.9473474830057714

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
d_reg = DecisionTreeRegressor(random_state=0)

# %%
d_reg.fit(x_train,y_train)
# Out:
# DecisionTreeRegressor(criterion='mse', max_depth=None, max_features=None,
#                       max_leaf_nodes=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       presort=False, random_state=0, splitter='best')

# %%
d_pred = d_reg.predict(x_test)

# %%
print(r2_score(y_test,d_pred))
# Out:
# 0.9555733315909787
